# %%
from helper import plot_mv_gaussian
import numpy as np

# %%
# %matplotlib inline
from ipywidgets import interactive, fixed

# %%
def plot_gauss(sigma_x1=1):
    plot_mv_gaussian(np.array([0, 0]), np.array([[sigma_x1,0],[0,1]]), N=50)
    return

# %%
w=interactive(plot_gauss, sigma_x1=(0.5,4))
w

# %%
plot_mv_gaussian(np.array([0, 0]), np.array([[1,0],[0,1]]), N=100, show=False)
