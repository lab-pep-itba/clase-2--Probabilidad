# %% [markdown]
# # V.A Uniforme

# %% [markdown]
# $P(X=x_i) = 1/N$
#
# N es la cantidad de salidas posibles del experimento

# %% [markdown]
# Ejemplo:
#
# Tirar un dado.
#
# N = 6

# %% [markdown]
# # Momentos de una V.A uniforme

# %% [markdown]
# $\huge \mu_x = \frac{A + B}{2}$
#
# $\huge \sigma_x^2 = \frac{(B-A + 1)^2 - 1}{12}$

# %% [markdown]
# # Modelo de una V.A uniforme

# %%
import numpy as np

# %%
np.random.randint(1,6, 1000)
# Out:
# array([4, 4, 3, 1, 2, 5, 2, 1, 5, 5, 2, 2, 3, 4, 4, 1, 3, 3, 1, 1, 1, 5,
#        5, 2, 3, 2, 3, 1, 4, 4, 4, 2, 4, 4, 5, 5, 2, 3, 5, 2, 4, 4, 4, 1,
#        1, 2, 4, 5, 4, 3, 5, 4, 5, 1, 3, 3, 5, 3, 3, 3, 3, 5, 4, 5, 5, 2,
#        3, 4, 4, 2, 4, 1, 4, 4, 4, 2, 4, 3, 2, 4, 1, 5, 4, 4, 4, 5, 2, 5,
#        4, 3, 3, 4, 3, 1, 1, 2, 2, 2, 2, 3, 2, 2, 1, 5, 5, 2, 1, 4, 1, 2,
#        4, 2, 5, 4, 2, 1, 5, 1, 5, 3, 1, 1, 5, 5, 1, 5, 3, 2, 1, 1, 4, 1,
#        1, 5, 1, 4, 1, 5, 2, 2, 3, 5, 4, 3, 4, 5, 3, 1, 2, 1, 2, 4, 5, 2,
#        5, 2, 2, 4, 2, 1, 1, 2, 5, 4, 2, 4, 5, 4, 1, 1, 1, 4, 1, 3, 2, 1,
#        5, 5, 1, 1, 5, 2, 3, 1, 1, 2, 3, 5, 4, 1, 5, 2, 1, 1, 2, 4, 2, 3,
#        3, 2, 2, 1, 2, 2, 2, 2, 1, 4, 4, 1, 1, 1, 5, 1, 1, 5, 3, 2, 2, 2,
#        3, 4, 2, 2, 4, 3, 2, 5, 3, 5, 5, 2, 2, 4, 5, 1, 2, 5, 1, 3, 5, 5,
#        1, 5, 5, 3, 5, 1, 3, 4, 5, 4, 2, 2, 2, 1, 4, 4, 2, 5, 5, 1, 5, 4,
#        1, 4, 3, 3, 2, 1, 3, 5, 5, 2, 5, 3, 2, 1, 4, 1, 1, 4, 1, 4, 4, 5,
#        3, 3, 2, 3, 5, 5, 2, 2, 1, 4, 5, 2, 1, 2, 1, 2, 3, 4, 2, 4, 4, 3,
#        1, 2, 4, 3, 2, 1, 2, 2, 3, 2, 1, 4, 1, 3, 2, 4, 2, 3, 4, 3, 5, 3,
#        2, 5, 3, 2, 3, 2, 2, 5, 3, 3, 2, 4, 1, 2, 2, 1, 2, 1, 4, 1, 4, 4,
#        2, 2, 5, 5, 3, 2, 5, 3, 3, 3, 3, 1, 4, 4, 1, 1, 4, 1, 5, 3, 5, 2,
#        3, 1, 3, 4, 5, 5, 1, 2, 3, 4, 1, 4, 2, 4, 5, 4, 2, 1, 2, 1, 5, 4,
#        1, 4, 5, 2, 4, 2, 5, 4, 5, 3, 5, 1, 1, 1, 2, 5, 1, 2, 2, 3, 1, 2,
#        1, 4, 3, 2, 2, 5, 1, 1, 3, 4, 2, 3, 3, 4, 4, 4, 3, 4, 4, 1, 4, 1,
#        2, 2, 4, 5, 5, 5, 4, 1, 2, 3, 2, 1, 1, 4, 5, 4, 2, 2, 3, 3, 4, 1,
#        1, 1, 5, 5, 1, 1, 4, 1, 3, 4, 2, 4, 2, 4, 5, 2, 2, 5, 5, 2, 3, 1,
#        3, 5, 3, 2, 2, 1, 4, 1, 2, 2, 3, 3, 3, 1, 4, 5, 3, 4, 5, 5, 4, 3,
#        4, 4, 3, 5, 2, 2, 5, 4, 3, 5, 1, 4, 5, 2, 1, 5, 1, 5, 5, 5, 1, 2,
#        1, 1, 5, 5, 5, 2, 3, 5, 4, 2, 1, 1, 1, 1, 1, 5, 2, 4, 5, 3, 4, 4,
#        5, 5, 5, 4, 3, 2, 5, 2, 1, 3, 1, 4, 3, 4, 3, 2, 1, 3, 2, 4, 3, 2,
#        4, 3, 5, 3, 4, 5, 5, 1, 1, 1, 1, 5, 1, 1, 4, 5, 5, 4, 1, 5, 5, 1,
#        3, 5, 5, 1, 5, 1, 1, 5, 3, 4, 3, 2, 5, 2, 1, 5, 3, 4, 4, 5, 3, 4,
#        5, 3, 3, 4, 5, 2, 3, 3, 5, 4, 4, 1, 2, 5, 1, 4, 2, 2, 5, 2, 1, 1,
#        5, 4, 4, 3, 1, 4, 5, 1, 1, 2, 3, 3, 5, 1, 1, 3, 2, 1, 5, 1, 5, 2,
#        4, 4, 5, 4, 5, 3, 3, 1, 1, 4, 4, 1, 3, 3, 2, 5, 1, 1, 4, 3, 4, 2,
#        3, 1, 5, 5, 4, 3, 3, 1, 3, 5, 2, 5, 1, 3, 5, 3, 1, 2, 1, 5, 1, 1,
#        5, 4, 5, 1, 1, 3, 1, 4, 5, 2, 3, 1, 4, 5, 1, 5, 2, 1, 1, 3, 2, 4,
#        1, 5, 1, 5, 4, 3, 1, 4, 1, 4, 5, 2, 4, 3, 4, 5, 1, 4, 1, 1, 1, 2,
#        3, 1, 1, 1, 2, 3, 5, 4, 3, 3, 1, 3, 4, 4, 5, 4, 5, 5, 3, 2, 1, 5,
#        3, 3, 1, 1, 4, 2, 4, 2, 4, 1, 3, 1, 3, 1, 3, 3, 5, 1, 5, 3, 5, 1,
#        3, 5, 3, 1, 3, 4, 2, 2, 3, 3, 3, 5, 2, 3, 2, 4, 3, 4, 4, 5, 1, 5,
#        4, 4, 1, 2, 5, 4, 3, 3, 4, 2, 5, 5, 1, 4, 1, 5, 4, 2, 2, 3, 3, 3,
#        1, 3, 4, 3, 2, 4, 4, 3, 3, 5, 5, 1, 5, 1, 2, 5, 5, 4, 2, 3, 4, 1,
#        2, 1, 2, 2, 4, 2, 4, 3, 5, 4, 5, 1, 2, 1, 1, 1, 5, 4, 2, 2, 2, 2,
#        2, 1, 5, 3, 5, 5, 5, 3, 1, 4, 1, 1, 1, 1, 4, 1, 3, 4, 4, 1, 3, 4,
#        5, 3, 4, 1, 2, 1, 2, 5, 4, 1, 1, 4, 5, 2, 1, 3, 1, 3, 5, 3, 3, 4,
#        4, 4, 4, 2, 4, 4, 1, 1, 3, 4, 5, 4, 3, 1, 4, 4, 1, 1, 2, 1, 5, 3,
#        4, 1, 1, 3, 5, 1, 2, 1, 2, 4, 4, 5, 2, 1, 4, 3, 5, 4, 3, 1, 3, 1,
#        5, 5, 5, 1, 3, 2, 1, 1, 1, 4, 1, 4, 2, 2, 5, 2, 1, 2, 3, 5, 4, 5,
#        5, 4, 5, 2, 5, 4, 5, 5, 2, 4])

# %% [markdown]
# # Cuando vale la entropia?

# %% [markdown]
# $S = - \sum_{i=1}^N{P_i log(P_i)}$
#
# $S = - \sum_{i=1}^N{1/N log(1/N)} = - log(1/N) = log(N)$

# %% [markdown]
# Si normalizo por logaritmo de la cantidad de salidas posibles N
#
# $S = 1$
